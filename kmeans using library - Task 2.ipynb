# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings("ignore")

image = imread("kmeans_1pic.jpg")
x = image.reshape(-1, 3)
kmeans = KMeans(n_clusters = 2, init = 'k-means++').fit(x)
kmeans.cluster_centers_ /= 255.0 # coordinates of the (k = 4) cluster centers, imported randomly that fits the reshaped image x
kmeans.cluster_centers_
segmented_image = kmeans.cluster_centers_[kmeans.labels_]
segmented_image = segmented_image.reshape(image.shape)

plt.figure(figsize = (12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(segmented_image)
plt.title("Segmented Image")
plt.axis("off")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings("ignore")

image = imread("kmeans_1pic.jpg")
x = image.reshape(-1, 3)
kmeans = KMeans(n_clusters = 3).fit(x)
kmeans.cluster_centers_ /= 255.0 # coordinates of the (k = 4) cluster centers, imported randomly that fits the reshaped image x
kmeans.cluster_centers_
segmented_image = kmeans.cluster_centers_[kmeans.labels_]
segmented_image = segmented_image.reshape(image.shape)

plt.figure(figsize = (12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(segmented_image)
plt.title("Segmented Image")
plt.axis("off")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings("ignore")

image = imread("kmeans_1pic.jpg")
x = image.reshape(-1, 3)
kmeans = KMeans(n_clusters = 10).fit(x)
kmeans.cluster_centers_ /= 255.0 # coordinates of the (k = 4) cluster centers, imported randomly that fits the reshaped image x
kmeans.cluster_centers_
segmented_image = kmeans.cluster_centers_[kmeans.labels_]
segmented_image = segmented_image.reshape(image.shape)

plt.figure(figsize = (12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(segmented_image)
plt.title("Segmented Image")
plt.axis("off")
plt.show()
