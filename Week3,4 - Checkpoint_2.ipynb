# %%
import random
import matplotlib.pyplot as plt
w = 1
b = 0
v = 1
points = []
for i in range(1000):
    x = random.uniform(0, 10)
    y = w*x + b
    y += random.gauss(0, v)
    points.append(y)
plt.plot(points)
plt.show()

# %% [markdown]
# ###
